# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# !curl -L "https://universe.roboflow.com/ds/l64LhySGXq?key=WkarOgC5jG" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %cd /content/yolov5
# !pip install -r requirements.txt
# !pip install "wandb==0.12.10"

# %%
# %cd ..
# Out:
# /content

# %%
# %mkdir dataset

# %%
# %mv test train valid data.yaml dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install protobuf==3.20.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
# %cd yolov5
# !python train.py --cfg yolov5s.yaml --weights '' --data /content/dataset/data.yaml --epochs 100
# Out:
# Streaming output truncated to the last 5000 lines.
#       60/99      4.88G    0.04211    0.01671    0.05911         41        640:  85% 50/59 [00:11<00:01,  4.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       60/99      4.88G    0.04212    0.01671    0.05894         40        640:  86% 51/59 [00:11<00:01,  4.59it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       60/99      4.88G    0.04214    0.01674     0.0587         44        640:  88% 52/59 [00:11<00:01,  4.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python val.py --weights runs/train/exp2/weights/best.pt --data /content/dataset/data.yaml --img-size 640 --batch-size 16
# Out:
# val: data=/content/dataset/data.yaml, weights=['runs/train/exp2/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7385008 parameters, 0 gradients, 16.9 GFLOPs
# val: Scanning /content/dataset/valid/labels.cache... 335 images, 7 backgrounds, 0 corrupt: 100% 335/335 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 21/21 [00:05<00:00,  3.70it/s]
#                    all        335        474      0.885      0.147      0.156     0.0904
# Speed: 0.3ms pre-process, 7.4ms inference, 3.4ms NMS per image at shape (16, 3, 640, 640)
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --source /content/dataset/test/images --img-size 640 --conf-thres 0.25 --iou-thres 0.45 --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7385008 parameters, 0 gradients, 16.9 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/162 /content/dataset/test/images/-_jpg.rf.dbc42647a8bf2893a5641a1348433e7a.jpg: 640x640 1 Horn Prohibited, 12.8ms
# ...

# %%
# !cp -r /content/yolov5 /content/drive/MyDrive/
