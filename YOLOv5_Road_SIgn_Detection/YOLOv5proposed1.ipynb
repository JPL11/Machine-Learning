# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# !curl -L "https://universe.roboflow.com/ds/OY780FX8wh?key=23LGUOdKv2" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %cd /content/yolov5
# !pip install -r requirements.txt
# !pip install "wandb==0.12.10"

# %%
# %cd ..
# Out:
# /content

# %%
# %mkdir dataset

# %%
# %mv test train valid data.yaml dataset
# Out:
# mv: cannot stat 'test': No such file or directory
# mv: cannot stat 'train': No such file or directory
# mv: cannot stat 'valid': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install protobuf==3.20.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
# %cd yolov5
# !python train.py --cfg yolov5s.yaml --weights '' --data /content/dataset/data.yaml --epochs 100
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       79/99      3.86G     0.0216   0.009611   0.004499         39        640:  88% 105/120 [00:14<00:02,  7.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       79/99      3.86G    0.02162   0.009631    0.00447         37        640:  88% 106/120 [00:14<00:01,  7.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       79/99      3.86G    0.02162   0.009614   0.004562         32        640:  89% 107/120 [00:14<00:01,  7.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data /content/dataset/data.yaml --img-size 640 --batch-size 16
# Out:
# val: data=/content/dataset/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7045186 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /content/dataset/valid/labels.cache... 188 images, 4 backgrounds, 0 corrupt: 100% 188/188 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 12/12 [00:03<00:00,  3.39it/s]
#                    all        188        219      0.936      0.915      0.925      0.738
#                      0        188         57       0.94      0.965       0.99      0.936
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source /content/dataset/test/images --img-size 640 --conf-thres 0.25 --iou-thres 0.45 --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7045186 parameters, 0 gradients, 15.9 GFLOPs
# image 1/94 /content/dataset/test/images/Test_img-25-_jpg.rf.0ba9692d6df5cd9ddc2d90a3c2d2027b.jpg: 640x640 1 9, 6.7ms
# image 2/94 /content/dataset/test/images/Test_img-32-_jpg.rf.0370600ef88ea12268adfcaa759916f7.jpg: 640x640 1 4, 7.0ms
# ...

# %%
# !cp -r /content/yolov5 /content/drive/MyDrive/
